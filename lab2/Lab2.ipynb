# %% [raw]
# Task1 a

# %%
import cv2
import matplotlib.pyplot as plt

img1_color = cv2.imread('pic1.jpg')  
img2_color = cv2.imread('pic2.jpg')


img1_gray = cv2.cvtColor(img1_color, cv2.COLOR_BGR2GRAY)
img2_gray = cv2.cvtColor(img2_color, cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()

keypoints1, descriptors1 = sift.detectAndCompute(img1_gray, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2_gray, None)

img1_with_circles = img1_color.copy()
img2_with_circles = img2_color.copy()

for kp in keypoints1:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img1_with_circles, (x, y), radius, (0, 0, 255), 2)  # 红色 (BGR: (0, 0, 255))

for kp in keypoints2:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img2_with_circles, (x, y), radius, (0, 0, 255), 2)  # 红色 (BGR: (0, 0, 255))

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img1_with_circles, cv2.COLOR_BGR2RGB)) 
plt.title('Input image 1')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(img2_with_circles, cv2.COLOR_BGR2RGB)) 
plt.title('Input image 2')

plt.show()

# %% [raw]
# Task1 b

# %%
sift = cv2.SIFT_create(nfeatures = 20)

keypoints1, descriptors1 = sift.detectAndCompute(img1_gray, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2_gray, None)


img1_with_circles = img1_color.copy()
img2_with_circles = img2_color.copy()


for kp in keypoints1:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img1_with_circles, (x, y), radius, (0, 0, 255), 6)  # 红色 (BGR: (0, 0, 255))


for kp in keypoints2:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img2_with_circles, (x, y), radius, (0, 0, 255), 6)  # 红色 (BGR: (0, 0, 255))


plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img1_with_circles, cv2.COLOR_BGR2RGB))  # 转换为RGB格式
plt.title('Image 1 with Reduced Keypoints')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(img2_with_circles, cv2.COLOR_BGR2RGB))  # 转换为RGB格式
plt.title('Image 2 with Reduced Keypoints')

plt.show()

# %% [raw]
# I filtered out the first 20 keypoints.

# %%
Task2 a

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img1_color = cv2.imread('pic1.jpg')
img2_color = cv2.imread('pic2.jpg')

sift = cv2.SIFT_create(nfeatures=20)

scale_factor = 1.2
img1_scaled = cv2.resize(img1_color, None, fx=scale_factor, fy=scale_factor)
img2_scaled = cv2.resize(img2_color, None, fx=scale_factor, fy=scale_factor)

keypoints1_scaled, descriptors1_scaled = sift.detectAndCompute(img1_scaled, None)
keypoints2_scaled, descriptors2_scaled = sift.detectAndCompute(img2_scaled, None)

img1_scaled_with_circles = img1_scaled
img2_scaled_with_circles = img2_scaled

for kp in keypoints1_scaled:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img1_scaled_with_circles, (x, y), radius, (0, 0, 255), 6)  # 红色

for kp in keypoints2_scaled:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img2_scaled_with_circles, (x, y), radius, (0, 0, 255), 6)  # 红色

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img1_color, cv2.COLOR_BGR2RGB))
plt.title('Image 1')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(img2_color, cv2.COLOR_BGR2RGB))
plt.title('Image 2')

plt.show()

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img1_scaled_with_circles, cv2.COLOR_BGR2RGB))
plt.title('Image 1 with Keypoints after Scaling')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(img2_scaled_with_circles, cv2.COLOR_BGR2RGB))
plt.title('Image 2 with Keypoints after Scaling')

plt.show()

# %%
Task2 b

# %%
rows1, cols1, _ = img1_color.shape
rows2, cols2, _ = img2_color.shape
M1 = cv2.getRotationMatrix2D((cols1/2, rows1/2), 60, 1)
M2 = cv2.getRotationMatrix2D((cols2/2, rows2/2), 60, 1)
img1_rotated = cv2.warpAffine(img1_color, M1, (cols1, rows1))
img2_rotated = cv2.warpAffine(img2_color, M2, (cols2, rows2))

keypoints1_rotated, descriptors1_rotated = sift.detectAndCompute(img1_rotated, None)
keypoints2_rotated, descriptors2_rotated = sift.detectAndCompute(img2_rotated, None)

img1_rotated_with_circles = img1_rotated
img2_rotated_with_circles = img2_rotated

for kp in keypoints1_rotated:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img1_rotated_with_circles, (x, y), radius, (0, 0, 255), 6)  # 红色

for kp in keypoints2_rotated:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img2_rotated_with_circles, (x, y), radius, (0, 0, 255), 6)  # 红色


plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img1_rotated_with_circles, cv2.COLOR_BGR2RGB))
plt.title('Image 1 with Keypoints after Rotation')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(img2_rotated_with_circles, cv2.COLOR_BGR2RGB))
plt.title('Image 2 with Keypoints after Rotation')

plt.show()

# %%
Task2 c

# %%
from skimage import img_as_ubyte
from skimage.util import random_noise
from skimage import img_as_ubyte

img1_noisy = img_as_ubyte(random_noise(img1_color, mode='s&p', amount=0.05))
img2_noisy = img_as_ubyte(random_noise(img2_color, mode='s&p', amount=0.05))

keypoints1_noisy, descriptors1_noisy = sift.detectAndCompute(img1_noisy, None)
keypoints2_noisy, descriptors2_noisy = sift.detectAndCompute(img2_noisy, None)

img1_noisy_with_circles = img1_noisy
img2_noisy_with_circles = img2_noisy

for kp in keypoints1_noisy:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img1_noisy_with_circles, (x, y), radius, (0, 0, 255), 6)  # 红色

for kp in keypoints2_noisy:
    x, y = int(kp.pt[0]), int(kp.pt[1])
    radius = int(kp.size / 2)
    cv2.circle(img2_noisy_with_circles, (x, y), radius, (0, 0, 255), 6)  # 红色

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img1_noisy_with_circles, cv2.COLOR_BGR2RGB))
plt.title('Image 1 with Keypoints after Noise')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(img2_noisy_with_circles, cv2.COLOR_BGR2RGB))
plt.title('Image 2 with Keypoints after Noise')

plt.show()

# %% [raw]
# The keypoints after scaling and rotation are similar to those in the original image, but some keypoints are lost in the noisy image. SIFT is more robust when handling images after affine transformations, but it struggles with noise.

# %%
Task3 a

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img1 = cv2.imread('pic1.jpg')  
img2 = cv2.imread('pic2.jpg')  

sift = cv2.SIFT_create(nfeatures=20)

keypoints1, descriptors1 = sift.detectAndCompute(img1, None)
keypoints2, descriptors2 = sift.detectAndCompute(img2, None)

bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=False)

matches = bf.knnMatch(descriptors1, descriptors2, k=2)

good_matches = []
for m, n in matches:
    if m.distance < 0.75 * n.distance: 
        good_matches.append(m)

img_matches = cv2.drawMatches(img1, keypoints1, img2, keypoints2, good_matches, None)

for m in good_matches:
    (x1, y1) = keypoints1[m.queryIdx].pt
    (x2, y2) = keypoints2[m.trainIdx].pt
    cv2.line(img_matches, (int(x1), int(y1)), (int(x2 + img1.shape[1]), int(y2)), (0, 0, 255), 2)

plt.figure(figsize=(15, 10))
plt.imshow(cv2.cvtColor(img_matches, cv2.COLOR_BGR2RGB))
plt.title('keypoints pair')
plt.axis('off')
plt.show()

# %%
dst_pts = np.float32([keypoints1[m.queryIdx].pt for m in good_matches]).reshape(-1, 1, 2)
src_pts = np.float32([keypoints2[m.trainIdx].pt for m in good_matches]).reshape(-1, 1, 2)

H, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC)

height, width, _ = img2.shape
img1_warped = cv2.warpPerspective(img2, H, (width + img2.shape[1], height))

img1_warped[0:height, 0:width] = img1



plt.figure(figsize=(15, 10))
plt.imshow(cv2.cvtColor(img1_warped, cv2.COLOR_BGR2RGB))
plt.title('Stiching pic')
plt.axis('off')
plt.show()
